# %% [markdown]
# # Connect to historic data API

# %%
# Free API, no credentials needed
import yfinance as yf

import pandas as pd

# %%
# Setup a connection
msft = yf.Ticker('MSFT')

# Get the Microsoft informatio 
msft.info
# Out:
# {'zip': '98052-6399',
#  'sector': 'Technology',
#  'fullTimeEmployees': 181000,
# ...

# %%
# All information here : https://pypi.org/project/yfinance/
# Out:
# {'zip': '98052-6399',
#  'sector': 'Technology',
#  'fullTimeEmployees': 181000,
# ...
